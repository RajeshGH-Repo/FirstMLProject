# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import pickle
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("C:\Rajesh Data\Machine Learning\Datasets\student_placement.csv")

# %%
data
# Out:
#      cgpa   iq  profile_score  placed
# 0    5.97  106             61       0
# 1    6.83  113             77       0
# 2    6.60  110             61       0
# 3    5.54  113             68       0
# 4    6.84  102             67       0
# ..    ...  ...            ...     ...
# 295  6.44  107             54       0
# 296  6.09  108             52       0
# 297  7.68  101             70       1
# 298  7.00   90             28       1
# 299  4.79  118             70       0
#
# [300 rows x 4 columns]

# %%
X = data.drop('placed', axis=1)
y = data['placed']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
scaler = StandardScaler()

# %%
X_train_trf = scaler.fit_transform(X=X_train)
X_test_trf = scaler.transform(X_test)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

# %%
pred = model.predict(X_test)

# %%
accuracy_score(y_test,pred)
# Out:
# 0.9

# %%
pickle.dump(model, open('SSmodel.pkl', 'wb'))

# %%
X_test
# Out:
#      cgpa   iq  profile_score
# 294  7.18  106             61
# 259  5.13  114             54
# 255  6.34  112             54
# 241  8.56  102             63
# 176  4.60  116             71
# 10   7.64  102             51
# 122  7.71  109             50
# 108  7.45  108             65
# 115  7.30  101             50
# 111  5.67  112             67
# 273  8.13   91             35
# 188  6.97  101             68
# 52   6.56  104             77
# 37   6.89  103             37
# 23   7.76   96             62
# 216  6.47  108             41
# 79   8.41   93             78
# 120  7.93   95             50
# 61   6.24  111             69
# 194  7.04   96             47
# 298  7.00   90             28
# 177  6.66  105             67
# 236  5.86  105             43
# 256  7.65   98             50
# 270  5.51  114             51
# 268  7.42   98             49
# 133  8.21   89             51
# 242  7.24  113             72
# 295  6.44  107             54
# 252  6.88   94             71
# ...

# %%
model.predict(np.array([8.56,102,63]).reshape(1,3))
# Out:
# array([1], dtype=int64)
